# %% [markdown]
# # Capstone project : Predict the probability of getting in an accident and the severity(week 2)

# %% [markdown]
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# #### 1-Business Problem

# %% [markdown]
# The mortality and morbidity rates from road traffic accidents are increasing annually in nearly all the developed countries. Despite all the causes of accidents, it will be great to know the probability of having an accident is huge or not so the conductor will be more conscious and more carefull on the road thus we can dicrease the number of accidents

# %% [markdown]
# #### 2- Data :

# %% [markdown]
# * we will be using the dataset provided by IBM course's

# %%
import pandas as pd 
data = pd.read_csv("./data/Data-Collisions.csv")
# Out:
# c:\users\oumaima\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0           NaN         NaN      NaN         10
# 1           NaN   6354039.0      NaN         11
# 2           NaN   4323031.0      NaN         32
# 3           NaN         NaN      NaN         23
# 4           NaN   4028032.0      NaN         10
#
#                                           ST_COLDESC  SEGLANEKEY  \
# 0                                  Entering at angle           0
# 1  From same direction - both going straight - bo...           0
# 2                             One parked--one moving           0
# 3                   From same direction - all others           0
# 4                                  Entering at angle           0
#
#    CROSSWALKKEY  HITPARKEDCAR
# 0             0             N
# 1             0             N
# 2             0             N
# 3             0             N
# 4             0             N
#
# [5 rows x 38 columns]

# %% [markdown]
# The datasets contains a lot of features that might infect the probability of getting in an accident or not like ROADCOND, LIGHTCOND...

# %%
data.shape
# Out:
# (194673, 38)

# %% [markdown]
# The dataset contains 194673 individuals and 38 features

# %% [markdown]
# Since we want to predict the severity of an accident, the target of our model will be the "SEVERITYCODE"

# %%
data.SEVERITYCODE.values
# Out:
# array([2, 1, 1, ..., 2, 2, 1], dtype=int64)

# %% [markdown]
# #### 3-Methodology

# %% [markdown]
# We will start by cleaning our dataset from any unrelated columns or meassing values, after that we will start our machine learning by using decision tree and RandomForest.

# %% [markdown]
# #### 4-Analysis

# %% [markdown]
# We have first to clean our dataset from any unrelatad column or messing values so we make sure to have a correct prediction

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns 
import matplotlib.pyplot as plt 
df = pd.read_csv("./data/Data-Collisions.csv")
# Out:
# c:\users\oumaima\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Get the ratio of column with above 80% of missing values

# %%
missing_df = df.isnull().sum(axis=0).reset_index()
missing_df.columns = ['columns_name','missing_count']
missing_df['missing_ratio'] = missing_df['missing_count'] /df.shape[0]
missing_df.loc[missing_df['missing_ratio']>0.777]
# Out:
#       columns_name  missing_count  missing_ratio
# 12   EXCEPTRSNDESC         189035       0.971039
# 25  INATTENTIONIND         164868       0.846897
# 30   PEDROWNOTGRNT         190006       0.976026
# 32        SPEEDING         185340       0.952058

# %%
df.dtypes
# Out:
# SEVERITYCODE        int64
# X                 float64
# Y                 float64
# OBJECTID            int64
# INCKEY              int64
# COLDETKEY           int64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC      object
# SEVERITYCODE.1      int64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT         int64
# PEDCOUNT            int64
# PEDCYLCOUNT         int64
# VEHCOUNT            int64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE        int64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# SEGLANEKEY          int64
# CROSSWALKKEY        int64
# HITPARKEDCAR       object
# dtype: object

# %%
x_cols = [col for col in df.columns if col not in ['SEVERITYCODE', 'SEVERITYCODE.1'] if (df[col].dtype=='float64' or df[col].dtype=='int64')]

labels = []
values = []
for col in x_cols:
    labels.append(col)
    values.append(np.corrcoef(df[col].values, df.SEVERITYCODE.values)[0,1])
corr_df = pd.DataFrame({'col_labels':labels, 'corr_values':values})
corr_df = corr_df.sort_values(by='corr_values')

ind = np.arange(len(labels))
width = 0.9
fig, ax = plt.subplots(figsize=(12,40))
rects = ax.barh(ind, np.array(corr_df.corr_values.values), color='y')
ax.set_yticks(ind)
ax.set_yticklabels(corr_df.col_labels.values, rotation='horizontal')
ax.set_xlabel("Correlation coefficient")
ax.set_title("Correlation coefficient of the variables")
plt.show()

# %% [markdown]
# we can detect that SDOTCOLUMN, INTKEY, Y,X , there is no correlation with the SEVERITYCODE

# %% [markdown]
# Let's get our highly correlated data

# %%
corr_df_sel = corr_df.loc[(corr_df['corr_values']>0.05) | (corr_df['corr_values'] < -0.05)]
corr_df_sel
# Out:
#       col_labels  corr_values
# 9       VEHCOUNT    -0.054686
# 12    SEGLANEKEY     0.104276
# 6    PERSONCOUNT     0.130949
# 13  CROSSWALKKEY     0.175093
# 10  SDOT_COLCODE     0.188905
# 8    PEDCYLCOUNT     0.214218
# 7       PEDCOUNT     0.246338

# %%
corr_df_ = corr_df_sel.col_labels.tolist()

tem_df = df[corr_df_]

corrmat = tem_df.corr(method='spearman')
fig,ax= plt.subplots(figsize=(8,8))

sns.heatmap(corrmat,vmax=1,square = True)
plt.title('corr map',fontsize=15)
plt.show()

# %%
fig=plt.gcf()
fig.set_size_inches(20,20)
fig=sns.heatmap(df.corr(),annot=True,linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %%
df.corr()
# Out:
#                 SEVERITYCODE         X         Y  OBJECTID    INCKEY  \
# SEVERITYCODE        1.000000  0.010309  0.017737  0.020131  0.022065
# X                   0.010309  1.000000 -0.160262  0.009956  0.010309
# Y                   0.017737 -0.160262  1.000000 -0.023848 -0.027396
# OBJECTID            0.020131  0.009956 -0.023848  1.000000  0.946383
# INCKEY              0.022065  0.010309 -0.027396  0.946383  1.000000
# COLDETKEY           0.022079  0.010300 -0.027415  0.945837  0.999996
# INTKEY              0.006553  0.120754 -0.114935  0.046929  0.048524
# SEVERITYCODE.1      1.000000  0.010309  0.017737  0.020131  0.022065
# PERSONCOUNT         0.130949  0.012887 -0.013850 -0.062333 -0.061500
# PEDCOUNT            0.246338  0.011304  0.010178  0.024604  0.024918
# PEDCYLCOUNT         0.214218 -0.001752  0.026304  0.034432  0.031342
# VEHCOUNT           -0.054686 -0.012168  0.017058 -0.094280 -0.107528
# SDOT_COLCODE        0.188905  0.010904 -0.019694 -0.037094 -0.027617
# SDOTCOLNUM          0.004226 -0.001016 -0.006958  0.969276  0.990571
# SEGLANEKEY          0.104276 -0.001618  0.004618  0.028076  0.019701
# CROSSWALKKEY        0.175093  0.013586  0.009508  0.056046  0.048179
#
#                 COLDETKEY    INTKEY  SEVERITYCODE.1  PERSONCOUNT  PEDCOUNT  \
# SEVERITYCODE     0.022079  0.006553        1.000000     0.130949  0.246338
# X                0.010300  0.120754        0.010309     0.012887  0.011304
# Y               -0.027415 -0.114935        0.017737    -0.013850  0.010178
# OBJECTID         0.945837  0.046929        0.020131    -0.062333  0.024604
# INCKEY           0.999996  0.048524        0.022065    -0.061500  0.024918
# COLDETKEY        1.000000  0.048499        0.022079    -0.061403  0.024914
# INTKEY           0.048499  1.000000        0.006553     0.001886 -0.004784
# SEVERITYCODE.1   0.022079  0.006553        1.000000     0.130949  0.246338
# PERSONCOUNT     -0.061403  0.001886        0.130949     1.000000 -0.023464
# PEDCOUNT         0.024914 -0.004784        0.246338    -0.023464  1.000000
# PEDCYLCOUNT      0.031296  0.000531        0.214218    -0.038809 -0.016920
# VEHCOUNT        -0.107598 -0.012929       -0.054686     0.380523 -0.261285
# SDOT_COLCODE    -0.027461  0.007114        0.188905    -0.128960  0.260393
# SDOTCOLNUM       0.990571  0.032604        0.004226     0.011784  0.021461
# SEGLANEKEY       0.019586 -0.010510        0.104276    -0.021383  0.001810
# CROSSWALKKEY     0.048063  0.018420        0.175093    -0.032258  0.565326
#
#                 PEDCYLCOUNT  VEHCOUNT  SDOT_COLCODE  SDOTCOLNUM  SEGLANEKEY  \
# SEVERITYCODE       0.214218 -0.054686      0.188905    0.004226    0.104276
# X                 -0.001752 -0.012168      0.010904   -0.001016   -0.001618
# Y                  0.026304  0.017058     -0.019694   -0.006958    0.004618
# OBJECTID           0.034432 -0.094280     -0.037094    0.969276    0.028076
# INCKEY             0.031342 -0.107528     -0.027617    0.990571    0.019701
# COLDETKEY          0.031296 -0.107598     -0.027461    0.990571    0.019586
# INTKEY             0.000531 -0.012929      0.007114    0.032604   -0.010510
# SEVERITYCODE.1     0.214218 -0.054686      0.188905    0.004226    0.104276
# PERSONCOUNT       -0.038809  0.380523     -0.128960    0.011784   -0.021383
# PEDCOUNT          -0.016920 -0.261285      0.260393    0.021461    0.001810
# PEDCYLCOUNT        1.000000 -0.253773      0.382521    0.034593    0.453657
# VEHCOUNT          -0.253773  1.000000     -0.365814   -0.023813   -0.122941
# SDOT_COLCODE       0.382521 -0.365814      1.000000   -0.041084    0.206835
# SDOTCOLNUM         0.034593 -0.023813     -0.041084    1.000000    0.066449
# SEGLANEKEY         0.453657 -0.122941      0.206835    0.066449    1.000000
# CROSSWALKKEY       0.109820 -0.200526      0.189518    0.086228   -0.003422
#
#                 CROSSWALKKEY
# SEVERITYCODE        0.175093
# X                   0.013586
# Y                   0.009508
# OBJECTID            0.056046
# INCKEY              0.048179
# COLDETKEY           0.048063
# INTKEY              0.018420
# SEVERITYCODE.1      0.175093
# PERSONCOUNT        -0.032258
# PEDCOUNT            0.565326
# PEDCYLCOUNT         0.109820
# VEHCOUNT           -0.200526
# SDOT_COLCODE        0.189518
# SDOTCOLNUM          0.086228
# SEGLANEKEY         -0.003422
# CROSSWALKKEY        1.000000

# %%
df=data[['SEVERITYCODE','ROADCOND','WEATHER','LIGHTCOND','ADDRTYPE','VEHCOUNT','PERSONCOUNT']]

# %% [markdown]
# we check how the the weather condition influence in accident's severity

# %%
df['WEATHER'].value_counts().sort_values(ascending=False).head(5).plot.bar(width=0.5,edgecolor='k',align='center',linewidth=2)
plt.xlabel('Weather_Condition')
plt.ylabel('Number of Accidents')
plt.title('5 Top Weather Condition for accidents')
plt.grid()
plt.ioff()

# %%
df['LIGHTCOND'].value_counts().sort_values(ascending=False).head(5).plot.bar(width=0.5,edgecolor='k',align='center',linewidth=2)
plt.xlabel('LIGHTCOND')
plt.ylabel('Number of Accidents')
plt.title('5 Top Light Condition for accidents')
plt.grid()
plt.ioff()

# %%
df['ROADCOND'].value_counts().sort_values(ascending=False).head(5).plot.bar(width=0.5,edgecolor='k',align='center',linewidth=2)
plt.xlabel('ROADCOND')
plt.ylabel('Number of Accidents')
plt.title('5 Top Road Condition for accidents')
plt.grid()
plt.ioff()

# %%
df['ADDRTYPE'].value_counts().sort_values(ascending=False).plot.bar(width=0.5,edgecolor='k',align='center',linewidth=2)
plt.xlabel('ADDRTYPE')
plt.ylabel('Number of Accidents')
plt.title('ADDRTYPE')
plt.grid()
plt.ioff()

# %% [markdown]
# ##### Decision Tree

# %% [markdown]
# Most of features are tyoe of object, we have to convert them to be numerical so wa could use them in our analysis

# %%
df["ROADCOND"] = df["ROADCOND"].astype('category')
df["ROADCOND_cat"] = df["ROADCOND"].cat.codes

df["LIGHTCOND"] = df["LIGHTCOND"].astype('category')
df["LIGHTCOND_cat"] = df["LIGHTCOND"].cat.codes

df["ADDRTYPE"] = df["ADDRTYPE"].astype('category')
df["ADDRTYPE_cat"] = df["ADDRTYPE"].cat.codes

df["WEATHER"] = df["WEATHER"].astype('category')
df["WEATHER_cat"] = df["WEATHER"].cat.codes

df.head()
# Out:
# <ipython-input-31-fdc2111d2108>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ROADCOND"] = df["ROADCOND"].astype('category')
# <ipython-input-31-fdc2111d2108>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ROADCOND_cat"] = df["ROADCOND"].cat.codes
# <ipython-input-31-fdc2111d2108>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LIGHTCOND"] = df["LIGHTCOND"].astype('category')
# <ipython-input-31-fdc2111d2108>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LIGHTCOND_cat"] = df["LIGHTCOND"].cat.codes
# <ipython-input-31-fdc2111d2108>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ADDRTYPE"] = df["ADDRTYPE"].astype('category')
# <ipython-input-31-fdc2111d2108>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ADDRTYPE_cat"] = df["ADDRTYPE"].cat.codes
# <ipython-input-31-fdc2111d2108>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["WEATHER"] = df["WEATHER"].astype('category')
# <ipython-input-31-fdc2111d2108>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["WEATHER_cat"] = df["WEATHER"].cat.codes
#    SEVERITYCODE ROADCOND   WEATHER                LIGHTCOND      ADDRTYPE  \
# 0             2      Wet  Overcast                 Daylight  Intersection
# 1             1      Wet   Raining  Dark - Street Lights On         Block
# 2             1      Dry  Overcast                 Daylight         Block
# 3             1      Dry     Clear                 Daylight         Block
# 4             2      Wet   Raining                 Daylight  Intersection
#
#    VEHCOUNT  PERSONCOUNT  ROADCOND_cat  LIGHTCOND_cat  ADDRTYPE_cat  \
# 0         2            2             8              5             2
# 1         2            2             8              2             1
# 2         3            4             0              5             1
# 3         3            3             0              5             1
# 4         2            2             8              5             2
#
#    WEATHER_cat
# 0            4
# 1            6
# 2            4
# 3            1
# 4            6

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X = np.asarray(df[['WEATHER_cat', 'ROADCOND_cat', 'LIGHTCOND_cat', 'ADDRTYPE_cat']])
Y = np.asarray(df['SEVERITYCODE'])

from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion="entropy", max_depth=7)
clf = clf.fit(X,Y)

# %%
# Out:
# [Text(210.7886029411765, 203.85, 'X[3] <= 1.5\nentropy = 0.88\nsamples = 194673\nvalue = [136485, 58188]'),
#  Text(132.0121323529412, 176.67000000000002, 'X[2] <= 7.5\nentropy = 0.785\nsamples = 129603\nvalue = [99234, 30369]'),
#  Text(73.2375, 149.49, 'X[0] <= 9.5\nentropy = 0.82\nsamples = 117373\nvalue = [87349, 30024]'),
#  Text(39.38823529411765, 122.31, 'X[2] <= 3.5\nentropy = 0.829\nsamples = 113636\nvalue = [83886, 29750]'),
#  Text(19.694117647058825, 95.13, 'X[2] <= 1.5\nentropy = 0.782\nsamples = 36676\nvalue = [28163, 8513]'),
#  Text(9.847058823529412, 67.94999999999999, 'X[0] <= 4.5\nentropy = 0.693\nsamples = 5461\nvalue = [4445, 1016]'),
#  Text(4.923529411764706, 40.77000000000001, 'X[1] <= 4.5\nentropy = 0.685\nsamples = 4952\nvalue = [4049, 903]'),
#  Text(2.461764705882353, 13.590000000000003, 'entropy = 0.69\nsamples = 4689\nvalue = [3823, 866]'),
#  Text(7.385294117647059, 13.590000000000003, 'entropy = 0.586\nsamples = 263\nvalue = [226, 37]'),
#  Text(14.770588235294118, 40.77000000000001, 'X[2] <= 0.5\nentropy = 0.764\nsamples = 509\nvalue = [396, 113]'),
#  Text(12.308823529411764, 13.590000000000003, 'entropy = 0.691\nsamples = 303\nvalue = [247, 56]'),
#  Text(17.232352941176472, 13.590000000000003, 'entropy = 0.851\nsamples = 206\nvalue = [149, 57]'),
#  Text(29.541176470588237, 67.94999999999999, 'X[1] <= 7.5\nentropy = 0.795\nsamples = 31215\nvalue = [23718, 7497]'),
#  Text(24.61764705882353, 40.77000000000001, 'X[1] <= 4.5\nentropy = 0.778\nsamples = 19827\nvalue = [15272, 4555]'),
#  Text(22.155882352941177, 13.590000000000003, 'entropy = 0.782\nsamples = 19226\nvalue = [14761, 4465]'),
#  Text(27.079411764705885, 13.590000000000003, 'entropy = 0.609\nsamples = 601\nvalue = [511, 90]'),
#  Text(34.464705882352945, 40.77000000000001, 'X[3] <= 0.5\nentropy = 0.824\nsamples = 11388\nvalue = [8446, 2942]'),
#  Text(32.00294117647059, 13.590000000000003, 'entropy = 0.604\nsamples = 115\nvalue = [98, 17]'),
#  Text(36.9264705882353, 13.590000000000003, 'entropy = 0.826\nsamples = 11273\nvalue = [8348, 2925]'),
#  Text(59.082352941176474, 95.13, 'X[3] <= 0.5\nentropy = 0.85\nsamples = 76960\nvalue = [55723, 21237]'),
#  Text(49.23529411764706, 67.94999999999999, 'X[3] <= -0.5\nentropy = 0.662\nsamples = 984\nvalue = [815, 169]'),
#  Text(44.311764705882354, 40.77000000000001, 'X[2] <= 5.5\nentropy = 0.704\nsamples = 596\nvalue = [482, 114]'),
#  Text(41.85, 13.590000000000003, 'entropy = 0.731\nsamples = 548\nvalue = [436, 112]'),
#  Text(46.773529411764706, 13.590000000000003, 'entropy = 0.25\nsamples = 48\nvalue = [46, 2]'),
#  Text(54.15882352941177, 40.77000000000001, 'X[2] <= 5.5\nentropy = 0.589\nsamples = 388\nvalue = [333, 55]'),
#  Text(51.69705882352942, 13.590000000000003, 'entropy = 0.572\nsamples = 369\nvalue = [319, 50]'),
#  Text(56.62058823529412, 13.590000000000003, 'entropy = 0.831\nsamples = 19\nvalue = [14, 5]'),
#  Text(68.92941176470589, 67.94999999999999, 'X[0] <= 7.5\nentropy = 0.852\nsamples = 75976\nvalue = [54908, 21068]'),
#  Text(64.00588235294119, 40.77000000000001, 'X[1] <= 7.5\nentropy = 0.852\nsamples = 75670\nvalue = [54649, 21021]'),
#  Text(61.544117647058826, 13.590000000000003, 'entropy = 0.847\nsamples = 59077\nvalue = [42909, 16168]'),
#  Text(66.46764705882353, 13.590000000000003, 'entropy = 0.872\nsamples = 16593\nvalue = [11740, 4853]'),
#  Text(73.8529411764706, 40.77000000000001, 'X[2] <= 6.5\nentropy = 0.619\nsamples = 306\nvalue = [259, 47]'),
#  Text(71.39117647058823, 13.590000000000003, 'entropy = 0.624\nsamples = 302\nvalue = [255, 47]'),
#  Text(76.31470588235294, 13.590000000000003, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(107.08676470588236, 122.31, 'X[1] <= 0.5\nentropy = 0.378\nsamples = 3737\nvalue = [3463, 274]'),
#  Text(89.85441176470589, 95.13, 'X[2] <= 4.5\nentropy = 0.693\nsamples = 425\nvalue = [346, 79]'),
#  Text(81.23823529411766, 67.94999999999999, 'X[2] <= -0.5\nentropy = 0.571\nsamples = 178\nvalue = [154, 24]'),
#  Text(78.7764705882353, 40.77000000000001, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(83.7, 40.77000000000001, 'X[1] <= -0.5\nentropy = 0.587\nsamples = 170\nvalue = [146, 24]'),
#  Text(81.23823529411766, 13.590000000000003, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(86.16176470588236, 13.590000000000003, 'entropy = 0.589\nsamples = 169\nvalue = [145, 24]'),
#  Text(98.47058823529412, 67.94999999999999, 'X[2] <= 5.5\nentropy = 0.765\nsamples = 247\nvalue = [192, 55]'),
#  Text(93.54705882352941, 40.77000000000001, 'X[1] <= -0.5\nentropy = 0.8\nsamples = 218\nvalue = [165, 53]'),
#  Text(91.08529411764707, 13.590000000000003, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(96.00882352941177, 13.590000000000003, 'entropy = 0.806\nsamples = 215\nvalue = [162, 53]'),
#  Text(103.39411764705883, 40.77000000000001, 'X[2] <= 6.5\nentropy = 0.362\nsamples = 29\nvalue = [27, 2]'),
#  Text(100.93235294117648, 13.590000000000003, 'entropy = 0.286\nsamples = 20\nvalue = [19, 1]'),
#  Text(105.85588235294118, 13.590000000000003, 'entropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(124.31911764705883, 95.13, 'X[1] <= 7.5\nentropy = 0.323\nsamples = 3312\nvalue = [3117, 195]'),
#  Text(118.16470588235295, 67.94999999999999, 'X[2] <= 3.0\nentropy = 0.288\nsamples = 3064\nvalue = [2910, 154]'),
#  Text(113.24117647058824, 40.77000000000001, 'X[1] <= 1.5\nentropy = 0.23\nsamples = 1045\nvalue = [1006, 39]'),
#  Text(110.77941176470588, 13.590000000000003, 'entropy = 0.503\nsamples = 18\nvalue = [16, 2]'),
#  Text(115.70294117647059, 13.590000000000003, 'entropy = 0.224\nsamples = 1027\nvalue = [990, 37]'),
#  Text(123.08823529411765, 40.77000000000001, 'X[1] <= 4.5\nentropy = 0.315\nsamples = 2019\nvalue = [1904, 115]'),
#  Text(120.6264705882353, 13.590000000000003, 'entropy = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(125.55000000000001, 13.590000000000003, 'entropy = 0.318\nsamples = 1998\nvalue = [1883, 115]'),
#  Text(130.4735294117647, 67.94999999999999, 'X[3] <= -0.5\nentropy = 0.647\nsamples = 248\nvalue = [207, 41]'),
#  Text(128.01176470588237, 40.77000000000001, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(132.93529411764706, 40.77000000000001, 'X[2] <= -0.5\nentropy = 0.632\nsamples = 245\nvalue = [206, 39]'),
#  Text(130.4735294117647, 13.590000000000003, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(135.39705882352942, 13.590000000000003, 'entropy = 0.624\nsamples = 244\nvalue = [206, 38]'),
#  Text(190.78676470588238, 149.49, 'X[0] <= 7.0\nentropy = 0.185\nsamples = 12230\nvalue = [11885, 345]'),
#  Text(171.09264705882353, 122.31, 'X[0] <= 3.5\nentropy = 0.297\nsamples = 2359\nvalue = [2235, 124]'),
#  Text(157.5529411764706, 95.13, 'X[1] <= 6.0\nentropy = 0.25\nsamples = 1750\nvalue = [1677, 73]'),
#  Text(147.7058823529412, 67.94999999999999, 'X[1] <= 4.0\nentropy = 0.271\nsamples = 1377\nvalue = [1313, 64]'),
#  Text(142.78235294117647, 40.77000000000001, 'X[0] <= 0.5\nentropy = 0.266\nsamples = 1371\nvalue = [1309, 62]'),
#  Text(140.32058823529414, 13.590000000000003, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(145.24411764705883, 13.590000000000003, 'entropy = 0.267\nsamples = 1364\nvalue = [1302, 62]'),
#  Text(152.62941176470588, 40.77000000000001, 'X[0] <= 0.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(150.16764705882355, 13.590000000000003, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(155.09117647058824, 13.590000000000003, 'entropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(167.4, 67.94999999999999, 'X[1] <= 7.5\nentropy = 0.164\nsamples = 373\nvalue = [364, 9]'),
#  Text(162.47647058823532, 40.77000000000001, 'X[3] <= 0.5\nentropy = 0.146\nsamples = 337\nvalue = [330, 7]'),
#  Text(160.01470588235296, 13.590000000000003, 'entropy = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(164.93823529411765, 13.590000000000003, 'entropy = 0.155\nsamples = 311\nvalue = [304, 7]'),
#  Text(172.32352941176472, 40.77000000000001, 'X[3] <= 0.0\nentropy = 0.31\nsamples = 36\nvalue = [34, 2]'),
#  Text(169.86176470588236, 13.590000000000003, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(174.78529411764706, 13.590000000000003, 'entropy = 0.187\nsamples = 35\nvalue = [34, 1]'),
#  Text(184.6323529411765, 95.13, 'X[3] <= -0.5\nentropy = 0.415\nsamples = 609\nvalue = [558, 51]'),
#  Text(182.17058823529413, 67.94999999999999, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(187.09411764705882, 67.94999999999999, 'X[3] <= 0.5\nentropy = 0.419\nsamples = 602\nvalue = [551, 51]'),
#  Text(182.17058823529413, 40.77000000000001, 'X[0] <= 5.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(179.70882352941177, 13.590000000000003, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(184.6323529411765, 13.590000000000003, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(192.01764705882354, 40.77000000000001, 'X[1] <= -0.5\nentropy = 0.415\nsamples = 598\nvalue = [548, 50]'),
#  Text(189.55588235294118, 13.590000000000003, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(194.4794117647059, 13.590000000000003, 'entropy = 0.416\nsamples = 596\nvalue = [546, 50]'),
#  Text(210.4808823529412, 122.31, 'X[3] <= 0.5\nentropy = 0.155\nsamples = 9871\nvalue = [9650, 221]'),
#  Text(201.86470588235295, 95.13, 'X[3] <= -0.5\nentropy = 0.111\nsamples = 875\nvalue = [862, 13]'),
#  Text(199.4029411764706, 67.94999999999999, 'X[1] <= 0.5\nentropy = 0.119\nsamples = 804\nvalue = [791, 13]'),
#  Text(196.94117647058823, 40.77000000000001, 'entropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(201.86470588235295, 40.77000000000001, 'X[1] <= 6.0\nentropy = 0.113\nsamples = 797\nvalue = [785, 12]'),
#  Text(199.4029411764706, 13.590000000000003, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(204.3264705882353, 13.590000000000003, 'entropy = 0.113\nsamples = 791\nvalue = [779, 12]'),
#  Text(204.3264705882353, 67.94999999999999, 'entropy = 0.0\nsamples = 71\nvalue = [71, 0]'),
#  Text(219.09705882352944, 95.13, 'X[1] <= 7.5\nentropy = 0.159\nsamples = 8996\nvalue = [8788, 208]'),
#  Text(216.63529411764708, 67.94999999999999, 'X[0] <= 9.5\nentropy = 0.157\nsamples = 8921\nvalue = [8717, 204]'),
#  Text(211.71176470588236, 40.77000000000001, 'X[1] <= 0.5\nentropy = 0.121\nsamples = 61\nvalue = [60, 1]'),
#  Text(209.25, 13.590000000000003, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(214.17352941176472, 13.590000000000003, 'entropy = 0.0\nsamples = 59\nvalue = [59, 0]'),
#  Text(221.55882352941177, 40.77000000000001, 'X[1] <= 0.5\nentropy = 0.157\nsamples = 8860\nvalue = [8657, 203]'),
#  Text(219.09705882352944, 13.590000000000003, 'entropy = 0.133\nsamples = 270\nvalue = [265, 5]'),
#  Text(224.02058823529413, 13.590000000000003, 'entropy = 0.158\nsamples = 8590\nvalue = [8392, 198]'),
#  Text(221.55882352941177, 67.94999999999999, 'entropy = 0.3\nsamples = 75\nvalue = [71, 4]'),
#  Text(289.5650735294118, 176.67000000000002, 'X[0] <= 9.5\nentropy = 0.985\nsamples = 65070\nvalue = [37251, 27819]'),
#  Text(260.33161764705886, 149.49, 'X[2] <= -0.5\nentropy = 0.987\nsamples = 63525\nvalue = [36028, 27497]'),
#  Text(241.2529411764706, 122.31, 'X[1] <= 4.5\nentropy = 0.847\nsamples = 1563\nvalue = [1135, 428]'),
#  Text(236.3294117647059, 95.13, 'X[1] <= 0.5\nentropy = 0.845\nsamples = 1556\nvalue = [1132, 424]'),
#  Text(233.86764705882354, 67.94999999999999, 'X[0] <= 6.5\nentropy = 0.845\nsamples = 1555\nvalue = [1131, 424]'),
#  Text(231.40588235294118, 40.77000000000001, 'X[1] <= -0.5\nentropy = 0.846\nsamples = 1554\nvalue = [1130, 424]'),
#  Text(228.94411764705885, 13.590000000000003, 'entropy = 0.845\nsamples = 1521\nvalue = [1107, 414]'),
#  Text(233.86764705882354, 13.590000000000003, 'entropy = 0.885\nsamples = 33\nvalue = [23, 10]'),
#  Text(236.3294117647059, 40.77000000000001, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(238.79117647058825, 67.94999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(246.1764705882353, 95.13, 'X[0] <= 5.0\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(243.71470588235294, 67.94999999999999, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(248.63823529411766, 67.94999999999999, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(279.4102941176471, 122.31, 'X[0] <= 6.5\nentropy = 0.988\nsamples = 61962\nvalue = [34893, 27069]'),
#  Text(263.4088235294118, 95.13, 'X[0] <= 2.5\nentropy = 0.989\nsamples = 61701\nvalue = [34716, 26985]'),
#  Text(253.56176470588235, 67.94999999999999, 'X[2] <= 2.5\nentropy = 0.99\nsamples = 39271\nvalue = [21955, 17316]'),
#  Text(248.63823529411766, 40.77000000000001, 'X[1] <= 0.5\nentropy = 0.985\nsamples = 8729\nvalue = [5003, 3726]'),
#  Text(246.1764705882353, 13.590000000000003, 'entropy = 0.985\nsamples = 8197\nvalue = [4680, 3517]'),
#  Text(251.10000000000002, 13.590000000000003, 'entropy = 0.967\nsamples = 532\nvalue = [323, 209]'),
#  Text(258.4852941176471, 40.77000000000001, 'X[2] <= 3.5\nentropy = 0.991\nsamples = 30542\nvalue = [16952, 13590]'),
#  Text(256.02352941176474, 13.590000000000003, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(260.9470588235294, 13.590000000000003, 'entropy = 0.991\nsamples = 30540\nvalue = [16952, 13588]'),
#  Text(273.25588235294117, 67.94999999999999, 'X[0] <= 4.5\nentropy = 0.986\nsamples = 22430\nvalue = [12761, 9669]'),
#  Text(268.3323529411765, 40.77000000000001, 'X[1] <= 0.5\nentropy = 0.983\nsamples = 9919\nvalue = [5728, 4191]'),
#  Text(265.8705882352941, 13.590000000000003, 'entropy = 0.987\nsamples = 5721\nvalue = [3251, 2470]'),
#  Text(270.79411764705884, 13.590000000000003, 'entropy = 0.976\nsamples = 4198\nvalue = [2477, 1721]'),
#  Text(278.1794117647059, 40.77000000000001, 'X[2] <= 4.5\nentropy = 0.989\nsamples = 12511\nvalue = [7033, 5478]'),
#  Text(275.71764705882356, 13.590000000000003, 'entropy = 0.992\nsamples = 5352\nvalue = [2964, 2388]'),
#  Text(280.6411764705883, 13.590000000000003, 'entropy = 0.986\nsamples = 7159\nvalue = [4069, 3090]'),
#  Text(295.4117647058824, 95.13, 'X[1] <= 6.5\nentropy = 0.906\nsamples = 261\nvalue = [177, 84]'),
#  Text(290.48823529411766, 67.94999999999999, 'X[1] <= 5.5\nentropy = 0.85\nsamples = 163\nvalue = [118, 45]'),
#  Text(288.0264705882353, 40.77000000000001, 'X[2] <= 7.5\nentropy = 0.855\nsamples = 161\nvalue = [116, 45]'),
#  Text(285.56470588235294, 13.590000000000003, 'entropy = 0.863\nsamples = 154\nvalue = [110, 44]'),
#  Text(290.48823529411766, 13.590000000000003, 'entropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(292.95, 40.77000000000001, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(300.3352941176471, 67.94999999999999, 'X[0] <= 7.5\nentropy = 0.97\nsamples = 98\nvalue = [59, 39]'),
#  Text(297.8735294117647, 40.77000000000001, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(302.7970588235294, 40.77000000000001, 'X[1] <= 7.5\nentropy = 0.977\nsamples = 95\nvalue = [56, 39]'),
#  Text(300.3352941176471, 13.590000000000003, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(305.25882352941176, 13.590000000000003, 'entropy = 0.973\nsamples = 94\nvalue = [56, 38]'),
#  Text(318.7985294117647, 149.49, 'X[2] <= 7.0\nentropy = 0.738\nsamples = 1545\nvalue = [1223, 322]'),
#  Text(312.64411764705886, 122.31, 'X[1] <= -0.5\nentropy = 0.888\nsamples = 645\nvalue = [448, 197]'),
#  Text(310.1823529411765, 95.13, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(315.1058823529412, 95.13, 'X[2] <= 5.5\nentropy = 0.887\nsamples = 644\nvalue = [448, 196]'),
#  Text(310.1823529411765, 67.94999999999999, 'X[2] <= -0.5\nentropy = 0.879\nsamples = 611\nvalue = [429, 182]'),
#  Text(307.72058823529414, 40.77000000000001, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(312.64411764705886, 40.77000000000001, 'X[2] <= 3.0\nentropy = 0.88\nsamples = 608\nvalue = [426, 182]'),
#  Text(310.1823529411765, 13.590000000000003, 'entropy = 0.867\nsamples = 208\nvalue = [148, 60]'),
#  Text(315.1058823529412, 13.590000000000003, 'entropy = 0.887\nsamples = 400\nvalue = [278, 122]'),
#  Text(320.0294117647059, 67.94999999999999, 'X[1] <= 3.5\nentropy = 0.983\nsamples = 33\nvalue = [19, 14]'),
#  Text(317.5676470588235, 40.77000000000001, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(322.49117647058824, 40.77000000000001, 'X[1] <= 7.5\nentropy = 0.999\nsamples = 27\nvalue = [13, 14]'),
#  Text(320.0294117647059, 13.590000000000003, 'entropy = 1.0\nsamples = 22\nvalue = [11, 11]'),
#  Text(324.95294117647063, 13.590000000000003, 'entropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(324.95294117647063, 122.31, 'X[1] <= 0.5\nentropy = 0.581\nsamples = 900\nvalue = [775, 125]'),
#  Text(322.49117647058824, 95.13, 'entropy = 0.946\nsamples = 11\nvalue = [7, 4]'),
#  Text(327.41470588235296, 95.13, 'X[1] <= 4.0\nentropy = 0.574\nsamples = 889\nvalue = [768, 121]'),
#  Text(324.95294117647063, 67.94999999999999, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(329.8764705882353, 67.94999999999999, 'X[1] <= 7.5\nentropy = 0.575\nsamples = 886\nvalue = [765, 121]'),
#  Text(327.41470588235296, 40.77000000000001, 'entropy = 0.572\nsamples = 878\nvalue = [759, 119]'),
#  Text(332.3382352941177, 40.77000000000001, 'entropy = 0.811\nsamples = 8\nvalue = [6, 2]')]
